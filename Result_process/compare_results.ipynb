# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm  # 用于颜色映射

# 定义模型列表
models = ["TCN", "GRU", "LSTM", "Informer"]

# 目标变量
targets = ["MRBT", "CUR", "OP"]

# 评估指标
metrics = ["MAE", "MSE", "RMSE", "MAPE(%)"]

# 你的数据
data_updated_8mins_latest = {
    "MRBT": {
        "MAE": [0.7886, 0.4512, 0.5354, 0.2796],
        "MSE": [0.8572, 0.3281, 0.4085, 0.1026],
        "RMSE": [0.9258, 0.5728, 0.6391, 0.3203],
        "MAPE(%)": [1.7010, 0.9345, 1.1331, 0.6079],
    },
    "CUR": {
        "MAE": [2.3650, 2.4452, 2.4416, 2.2958],
        "MSE": [9.1682, 9.5768, 11.0237, 9.0529],
        "RMSE": [3.0279, 3.0946, 3.3202, 3.0088],
        "MAPE(%)": [3.9829, 4.1183, 4.0906, 3.8501],
    },
    "OP": {
        "MAE": [0.1805, 0.1796, 0.1721, 0.1657],
        "MSE": [0.0559, 0.0539, 0.0507, 0.0478],
        "RMSE": [0.2364, 0.2321, 0.2252, 0.2185],
        "MAPE(%)": [17.8849, 18.0381, 16.9109, 16.0202],
    },
}

# 创建分组柱状图
fig, axes = plt.subplots(1, 3, figsize=(18, 6), dpi=300)
plt.subplots_adjust(wspace=0.4)  # 增加子图之间的间距

# 遍历每个目标变量并绘制柱状图
for i, (target, ax) in enumerate(zip(targets, axes)):
    df_target = pd.DataFrame(data_updated_8mins_latest[target], index=models).T
    colors = cm.viridis(np.linspace(0, 1, len(models)))  # 生成不同颜色

    df_target.plot(kind="bar", ax=ax, width=0.8, color=colors)

    ax.set_title(f"Grouped Bar Chart for {target} (8mins)", fontsize=16)
    ax.set_ylabel("Performance Metrics", fontsize=12)
    ax.set_xticklabels(metrics, rotation=30, fontsize=12)
    ax.legend(title="Models", fontsize=10, loc="upper left")
    ax.grid(axis="y", linestyle="--", alpha=0.7)

plt.tight_layout()
plt.savefig(r"C:\Users\13844\Desktop\papers\paper4\png\对比图\local\Grouped_Bar_Charts_8MINS_Latest.png", dpi=300)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm  # 用于颜色映射

# 定义模型列表
models = ["TCN", "GRU", "LSTM", "Informer"]

# 目标变量
targets = ["MRBT", "CUR", "OP"]

# 评估指标
metrics = ["MAE", "MSE", "RMSE", "MAPE(%)"]

# Updated data for 16MINS with the newly provided parameters
data_updated_16mins_latest = {
    "MRBT": {
        "MAE": [0.7137, 0.5372, 0.5654, 0.4792],
        "MSE": [0.7096, 0.4303, 0.4356, 0.3165],
        "RMSE": [0.8424, 0.6560, 0.6600, 0.5626],
        "MAPE(%)": [1.5162, 1.1305, 1.2178, 1.0393],
    },
    "CUR": {
        "MAE": [3.2107, 3.0378, 3.1670, 2.6658],
        "MSE": [17.2165, 15.3883, 15.0960, 11.7643],
        "RMSE": [4.1493, 3.9228, 3.8854, 3.4299],
        "MAPE(%)": [5.4292, 5.1468, 5.3586, 4.4826],
    },
    "OP": {
        "MAE": [0.2106, 0.2112, 0.2091, 0.1911],
        "MSE": [0.0701, 0.0684, 0.0670, 0.0609],
        "RMSE": [0.2647, 0.2616, 0.2588, 0.2467],
        "MAPE(%)": [21.1897, 21.2941, 20.7760, 19.0207],
    },
}


# Create the grouped bar charts with performance metrics as x-axis and models as legend
fig, axes = plt.subplots(1, 3, figsize=(18, 6), dpi=300)
plt.subplots_adjust(wspace=0.4)  # Increase space between the plots

# Loop through each target and create a bar chart
for i, (target, ax) in enumerate(zip(targets, axes)):
    # Transpose data to have metrics as x-axis and models as legend
    df_target = pd.DataFrame(data_updated_16mins_latest[target], index=models).T
    colors = cm.viridis(np.linspace(0, 1, len(models)))  # Assign unique colors to each model

    # Plot grouped bar chart
    df_target.plot(kind="bar", ax=ax, width=0.8, color=colors)
    
    # Set titles and labels
    ax.set_title(f"Grouped Bar Chart for {target} (16mins)", fontsize=16)
    ax.set_ylabel("Performance Metrics", fontsize=12)
    ax.set_xticklabels(metrics, rotation=30, fontsize=12)
    ax.legend(title="Models", fontsize=10, loc="upper left")
    ax.grid(axis="y", linestyle="--", alpha=0.7)

# Save and display the plot
plt.tight_layout()
plt.savefig(r"C:\Users\13844\Desktop\papers\paper4\png\对比图\local\Grouped_Bar_Charts_16MINS_Latest.png", dpi=300)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm  # 用于颜色映射

# 定义模型列表
models = ["TCN", "GRU", "LSTM", "Informer"]

# 目标变量
targets = ["MRBT", "CUR", "OP"]

# 评估指标
metrics = ["MAE", "MSE", "RMSE", "MAPE(%)"]
# Updated data for 2MINS with the newly provided values
data_updated_2mins = {
    "MRBT": {
        "MAE": [0.2563, 0.3680, 0.5302, 0.2011],
        "MSE": [0.0940, 0.2240, 0.4941, 0.0669],
        "RMSE": [0.3066, 0.4733, 0.7029, 0.2587],
        "MAPE(%)": [0.5448, 0.7650, 1.0907, 0.4216],
    },
    "CUR": {
        "MAE": [1.8303, 1.9962, 2.2287, 1.6370],
        "MSE": [6.7796, 7.1779, 7.9856, 5.7509],
        "RMSE": [2.6038, 2.6792, 2.8259, 2.3981],
        "MAPE(%)": [3.0269, 3.3254, 3.7286, 2.6958],
    },
    "OP": {
        "MAE": [0.1405, 0.1409, 0.1529, 0.1307],
        "MSE": [0.0380, 0.0378, 0.0405, 0.0348],
        "RMSE": [0.1950, 0.1945, 0.2012, 0.1865],
        "MAPE(%)": [13.2427, 13.4145, 14.7921, 12.1756],
    },
}

# Create the grouped bar charts with performance metrics as x-axis and models as legend
fig, axes = plt.subplots(1, 3, figsize=(18, 6), dpi=300)
plt.subplots_adjust(wspace=0.4)  # Increase space between the plots

# Loop through each target and create a bar chart
for i, (target, ax) in enumerate(zip(targets, axes)):
    # Transpose data to have metrics as x-axis and models as legend
    df_target = pd.DataFrame(data_updated_2mins[target], index=models).T
    colors = cm.viridis(np.linspace(0, 1, len(models)))  # Assign unique colors to each model

    # Plot grouped bar chart
    df_target.plot(kind="bar", ax=ax, width=0.8, color=colors)
    
    # Set titles and labels
    ax.set_title(f"Grouped Bar Chart for {target} (2mins)", fontsize=16)
    ax.set_ylabel("Performance Metrics", fontsize=12)
    ax.set_xticklabels(metrics, rotation=30, fontsize=12)
    ax.legend(title="Models", fontsize=10, loc="upper left")
    ax.grid(axis="y", linestyle="--", alpha=0.7)

# Save and display the plot
plt.tight_layout()
plt.savefig(r"C:\Users\13844\Desktop\papers\paper4\png\对比图\local\Grouped_Bar_Charts_2MINS_Latest.png", dpi=300)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm  # 用于颜色映射

# 定义模型列表
models = ["TCN", "GRU", "LSTM", "Informer"]

# 目标变量
targets = ["MRBT", "CUR", "OP"]

# 评估指标
metrics = ["MAE", "MSE", "RMSE", "MAPE(%)"]
# Updated data for 2MINS with the newly provided values
# Updated data for 4MINS with new values
data_updated_4mins = {
    "MRBT": {
        "MAE": [0.3652, 0.6090, 0.3768, 0.3099],
        "MSE": [0.1762, 0.5170, 0.2440, 0.1621],
        "RMSE": [0.4198, 0.7190, 0.4940, 0.4027],
        "MAPE(%)": [0.7834, 1.2757, 0.7908, 0.6446],
    },
    "CUR": {
        "MAE": [2.3466, 2.1022, 2.2331, 1.7033],
        "MSE": [8.8506, 7.9532, 7.9843, 6.4676],
        "RMSE": [2.9750, 2.8201, 2.8257, 2.5432],
        "MAPE(%)": [3.9442, 3.5057, 3.7492, 2.7978],
    },
    "OP": {
        "MAE": [0.1642, 0.1594, 0.1619, 0.1497],
        "MSE": [0.0455, 0.0451, 0.0449, 0.0425],
        "RMSE": [0.2133, 0.2123, 0.2119, 0.2061],
        "MAPE(%)": [16.3169, 15.5173, 16.0187, 13.9464],
    },
}

# Create the grouped bar charts with performance metrics as x-axis and models as legend
fig, axes = plt.subplots(1, 3, figsize=(18, 6), dpi=300)
plt.subplots_adjust(wspace=0.4)  # Increase space between the plots

# Loop through each target and create a bar chart
for i, (target, ax) in enumerate(zip(targets, axes)):
    # Transpose data to have metrics as x-axis and models as legend
    df_target = pd.DataFrame(data_updated_4mins[target], index=models).T
    colors = cm.viridis(np.linspace(0, 1, len(models)))  # Assign unique colors to each model

    # Plot grouped bar chart
    df_target.plot(kind="bar", ax=ax, width=0.8, color=colors)
    
    # Set titles and labels
    ax.set_title(f"Grouped Bar Chart for {target} (4mins)", fontsize=16)
    ax.set_ylabel("Performance Metrics", fontsize=12)
    ax.set_xticklabels(metrics, rotation=30, fontsize=12)
    ax.legend(title="Models", fontsize=10, loc="upper left")
    ax.grid(axis="y", linestyle="--", alpha=0.7)

# Save and display the plot
# Save and display the plot
plt.tight_layout()
plt.savefig(r"C:\Users\13844\Desktop\papers\paper4\png\对比图\local\Grouped_Bar_Charts_4MINS_Latest.png", dpi=300)
plt.show()
